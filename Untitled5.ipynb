# %%
import os
from tqdm import tqdm
import copy
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
from collections import Counter
from PIL import Image
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {device}')
# Out:
# Device: cpu

# %%
def setSeed(seed=42):
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

setSeed()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_dir = '/content/drive/MyDrive/The IQ-OTHNCCD lung cancer dataset'

# %%
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor()
])

data_dir = '/content/drive/MyDrive/The IQ-OTHNCCD lung cancer dataset'
dataset = datasets.ImageFolder(root=data_dir, transform=transform)

print(f'Classes: {dataset.classes}')
print(f'Total images: {len(dataset)}')
# Out:
# Classes: ['Bengin cases', 'Malignant cases', 'Normal cases']
# Total images: 1097

# %%
class_counts = Counter([label for _, label in dataset.samples])
classes = list(dataset.classes)
counts = [class_counts[i] for i in range(len(classes))]

plt.bar(classes, counts, color='orange')

plt.title('Class Distribution', fontsize=16)
plt.xlabel('Class', fontsize=12)
plt.ylabel('Image Count', fontsize=12)
plt.show()

for cls, cnt in zip(classes, counts):
    print(f"{cls:10s} : {cnt}")
# Out:
# Bengin cases : 120
# Malignant cases : 561
# Normal cases : 416

# %%
dataset = datasets.ImageFolder(root=data_dir, transform=transform)

train_size = int(0.7 * len(dataset))
val_size = int(0.15 * len(dataset))
test_size = len(dataset) - train_size - val_size

train_ds, val_ds, test_ds = random_split(dataset, [train_size, val_size, test_size])

train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=32, shuffle=False)
test_loader = DataLoader(test_ds, batch_size=32, shuffle=False)

print(f'Train: {len(train_ds)}, Val: {len(val_ds)}, Test: {len(test_ds)}')
# Out:
# Train: 767, Val: 164, Test: 166

# %%
n_per_class = 4

samples = dataset.samples
classes = dataset.classes

fig, axes = plt.subplots(len(classes), n_per_class, figsize=(n_per_class * 4, len(classes) * 4))

for i, cls in enumerate(classes):
    cls_imgs = [path for path, label in samples if label == i][:n_per_class]

    for j, path in enumerate(cls_imgs):
        img = Image.open(path)
        axes[i, j].imshow(img)
        axes[i, j].axis('off')

        label = os.path.splitext(os.path.basename(path))[0]
        axes[i, j].set_title(label, fontsize=10, pad=5)

        if j == 0:
            axes[i, j].set_ylabel(cls, rotation=0, labelpad=30, fontsize=14, weight='bold')

plt.tight_layout()
plt.show()

# %%
class LungCNN(nn.Module):
    def __init__(self, num_classes=3):
        super(LungCNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),

            nn.Conv2d(32, 64, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),

            nn.AdaptiveAvgPool2d((6, 6))
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 6 * 6, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

model = LungCNN(num_classes=3).to(device)
print(model)
# Out:
# LungCNN(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): AdaptiveAvgPool2d(output_size=(6, 6))
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=2304, out_features=256, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=256, out_features=3, bias=True)
#   )
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
num_epochs = 50
best_val_acc = 0.0
best_val_loss = np.inf
best_model_wts = copy.deepcopy(model.state_dict())

os.makedirs('checkpoints', exist_ok=True)
save_path = 'checkpoints/model.pth'

train_losses, val_losses, val_accuracies = [], [], []

for epoch in range(num_epochs):
    print(f"\nEpoch {epoch+1}/{num_epochs}")
    print("-" * 40)

    model.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0

    for images, labels in tqdm(train_loader, desc='Training', leave=False):
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct_train / total_train

    model.eval()
    val_loss = 0.0
    correct_val = 0
    total_val = 0

    with torch.no_grad():
        for images, labels in tqdm(val_loader, desc='Validation', leave=True):
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    val_loss /= len(val_loader)
    val_acc = 100 * correct_val / total_val

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    val_accuracies.append(val_acc)

    print(f'Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}%')
    print(f'Val   Loss: {val_loss:.4f} | Val   Acc: {val_acc:.2f}%')

    if val_loss < best_val_loss:
        best_val_acc = val_acc
        best_val_loss = val_loss
        best_model_wts = copy.deepcopy(model.state_dict())
        torch.save(best_model_wts, save_path)
        print(f'Best model updated and saved (Val Loss: {val_loss:.2f})')

print("\nTraining complete")
print(f'Best Validation Accuracy (with minimal loss): {best_val_acc:.2f}%')

model.load_state_dict(best_model_wts)
print('Restored best model weights')
# Out:
# Epoch 1/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:35<00:00,  5.96s/it]
# Train Loss: 0.9781 | Train Acc: 49.28%
# Val   Loss: 0.9402 | Val   Acc: 52.44%
# Best model updated and saved (Val Loss: 0.94)
#
# Epoch 2/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.62it/s]
# Train Loss: 0.9265 | Train Acc: 51.76%
# Val   Loss: 0.9179 | Val   Acc: 57.93%
# Best model updated and saved (Val Loss: 0.92)
#
# Epoch 3/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1
50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:07<00:00,  1.23s/it]
# Train Loss: 0.5349 | Train Acc: 78.10%
# Val   Loss: 0.4885 | Val   Acc: 77.44%
# Best model updated and saved (Val Loss: 0.49)
#
# Epoch 20/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.56it/s]
# Train Loss: 0.5163 | Train Acc: 80.05%
# Val   Loss: 0.4706 | Val   Acc: 80.49%
# Best model updated and saved (Val Loss: 0.47)
#
# Epoch 21/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:04<00:00,  1.25it/s]
# Train Loss: 0.5138 | Train Acc: 79.66%
# Val   Loss: 0.4783 | Val   Acc: 80.49%
#
# Epoch 22/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.88it/s]
# Train Loss: 0.4892 | Train Acc: 79.79%
# Val   Loss: 0.4923 | Val   Acc: 81.10%
#
# Epoch 23/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.60it/s]
# Train Loss: 0.5082 | Train Acc: 80.83%
# Val   Loss: 0.4633 | Val   Acc: 82.32%
# Best model updated and saved (Val Loss: 0.46)
#
# Epoch 24/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.50it/s]
# Train Loss: 0.4870 | Train Acc: 80.18%
# Val   Loss: 0.4730 | Val   Acc: 81.71%
#
# Epoch 25/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.84it/s]
# Train Loss: 0.5017 | Train Acc: 79.92%
# Val   Loss: 0.4599 | Val   Acc: 82.32%
# Best model updated and saved (Val Loss: 0.46)
#
# Epoch 26/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.50it/s]
# Train Loss: 0.4672 | Train Acc: 81.10%
# Val   Loss: 0.4407 | Val   Acc: 82.93%
# Best model updated and saved (Val Loss: 0.44)
#
# Epoch 27/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.57it/s]
# Train Loss: 0.4152 | Train Acc: 83.57%
# Val   Loss: 0.4032 | Val   Acc: 83.54%
# Best model updated and saved (Val Loss: 0.40)
#
# Epoch 28/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.63it/s]
# Train Loss: 0.4156 | Train Acc: 82.92%
# Val   Loss: 0.4791 | Val   Acc: 83.54%
#
# Epoch 29/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:04<00:00,  1.48it/s]
# Train Loss: 0.4380 | Train Acc: 83.18%
# Val   Loss: 0.3913 | Val   Acc: 85.37%
# Best model updated and saved (Val Loss: 0.39)
#
# Epoch 30/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.84it/s]
# Train Loss: 0.4064 | Train Acc: 83.57%
# Val   Loss: 0.4060 | Val   Acc: 83.54%
#
# Epoch 31/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:04<00:00,  1.27it/s]
# Train Loss: 0.3985 | Train Acc: 84.75%
# Val   Loss: 0.3931 | Val   Acc: 84.76%
#
# Epoch 32/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.63it/s]
# Train Loss: 0.3651 | Train Acc: 84.88%
# Val   Loss: 0.3978 | Val   Acc: 85.37%
#
# Epoch 33/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:04<00:00,  1.49it/s]
# Train Loss: 0.4380 | Train Acc: 81.49%
# Val   Loss: 0.4010 | Val   Acc: 84.15%
#
# Epoch 34/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.63it/s]
# Train Loss: 0.3750 | Train Acc: 85.27%
# Val   Loss: 0.3654 | Val   Acc: 82.93%
# Best model updated and saved (Val Loss: 0.37)
#
# Epoch 35/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.58it/s]
# Train Loss: 0.3650 | Train Acc: 84.75%
# Val   Loss: 0.3661 | Val   Acc: 84.76%
#
# Epoch 36/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.65it/s]
# Train Loss: 0.3404 | Train Acc: 87.35%
# Val   Loss: 0.3269 | Val   Acc: 86.59%
# Best model updated and saved (Val Loss: 0.33)
#
# Epoch 37/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:04<00:00,  1.42it/s]
# Train Loss: 0.3506 | Train Acc: 85.53%
# Val   Loss: 0.3641 | Val   Acc: 85.98%
#
# Epoch 38/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.89it/s]
# Train Loss: 0.3276 | Train Acc: 86.31%
# Val   Loss: 0.3162 | Val   Acc: 85.98%
# Best model updated and saved (Val Loss: 0.32)
#
# Epoch 39/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.61it/s]
# Train Loss: 0.3101 | Train Acc: 86.44%
# Val   Loss: 0.3869 | Val   Acc: 87.20%
#
# Epoch 40/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.53it/s]
# Train Loss: 0.3259 | Train Acc: 86.96%
# Val   Loss: 0.3807 | Val   Acc: 85.98%
#
# Epoch 41/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.93it/s]
# Train Loss: 0.3372 | Train Acc: 85.53%
# Val   Loss: 0.3303 | Val   Acc: 87.20%
#
# Epoch 42/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:04<00:00,  1.37it/s]
# Train Loss: 0.3171 | Train Acc: 85.66%
# Val   Loss: 0.3611 | Val   Acc: 86.59%
#
# Epoch 43/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.84it/s]
# Train Loss: 0.3193 | Train Acc: 87.35%
# Val   Loss: 0.3134 | Val   Acc: 89.63%
# Best model updated and saved (Val Loss: 0.31)
#
# Epoch 44/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.62it/s]
# Train Loss: 0.2783 | Train Acc: 87.22%
# Val   Loss: 0.3600 | Val   Acc: 87.80%
#
# Epoch 45/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:04<00:00,  1.45it/s]
# Train Loss: 0.2609 | Train Acc: 89.70%
# Val   Loss: 0.2825 | Val   Acc: 88.41%
# Best model updated and saved (Val Loss: 0.28)
#
# Epoch 46/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.60it/s]
# Train Loss: 0.2411 | Train Acc: 90.74%
# Val   Loss: 0.3083 | Val   Acc: 89.63%
#
# Epoch 47/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:04<00:00,  1.41it/s]
# Train Loss: 0.2987 | Train Acc: 88.66%
# Val   Loss: 0.3112 | Val   Acc: 89.63%
#
# Epoch 48/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.63it/s]
# Train Loss: 0.2822 | Train Acc: 88.40%
# Val   Loss: 0.3083 | Val   Acc: 89.02%
#
# Epoch 49/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:04<00:00,  1.49it/s]
# Train Loss: 0.2710 | Train Acc: 89.18%
# Val   Loss: 0.2845 | Val   Acc: 87.20%
#
# Epoch 50/50
# ----------------------------------------
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.67it/s]
# Train Loss: 0.2703 | Train Acc: 87.74%
# Val   Loss: 0.2738 | Val   Acc: 89.02%
# Best model updated and saved (Val Loss: 0.27)
#
# Training complete
# Best Validation Accuracy (with minimal loss): 89.02%
# Restored best model weights

# %%
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.legend()
plt.title('Training vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
model.eval()
y_true, y_pred = [], []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())

print(classification_report(y_true, y_pred, target_names=dataset.classes))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=dataset.classes,
            yticklabels=dataset.classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
#                  precision    recall  f1-score   support
#
#    Bengin cases       0.67      0.24      0.35        17
# Malignant cases       0.97      1.00      0.98        86
#    Normal cases       0.82      0.92      0.87        63
#
#        accuracy                           0.89       166
#       macro avg       0.82      0.72      0.73       166
#    weighted avg       0.88      0.89      0.87       166
